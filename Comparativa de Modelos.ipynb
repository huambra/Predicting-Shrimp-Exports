# %%
import pandas as pd
import matplotlib.pyplot as plt

###############################################################################
# 1. MÉTRICAS OBTENIDAS DE LOS MODELOS
###############################################################################

# Resultados SARIMA (ya proporcionados en tu código original)
# Resultados Random Forest (de la imagen)
rforest_china_base = [14354.22, 15905.14, 24.31]
rforest_china_ft = [14565.94, 16003.35, 24.70]
rforest_usa_base = [4207.72, 6427.25, 19.77]
rforest_usa_ft = [3958.90, 6295.97, 18.23]
rforest_ue_base = [3171.52, 4732.29, 18.24]
rforest_ue_ft = [2979.67, 4630.26, 17.42]

# Valores ficticios para LSTM (modelo base y fine-tuned)
lstm_china_base = [12000.00, 14000.00, 20.00]
lstm_china_ft = [11500.00, 13500.00, 19.50]
lstm_usa_base = [3500.00, 5000.00, 18.00]
lstm_usa_ft = [3300.00, 4800.00, 17.50]
lstm_ue_base = [2800.00, 4200.00, 16.50]
lstm_ue_ft = [2600.00, 4000.00, 15.80]

###############################################################################
# 2. CREAR TABLA COMPARATIVA EN PANDAS
###############################################################################

model_names = [
    "SARIMA Base", "SARIMA CV", "SARIMA CV Mes a Mes", "SARIMA Log",
    "SARIMA Box-Cox", "SARIMA 2020+",
    "RF Base", "RF Fine-Tuned",
    "LSTM Base", "LSTM Fine-Tuned"
]

# Consolidar los resultados para cada país
china_metrics = [
    [6380.30, 7763.23, 12.38], [7545.44, 7545.44, 14.22], [7292.14, 8301.72, 13.85],
    [8181.65, 9858.39, 15.74], [7903.00, 9053.29, 14.94], [8838.79, 10451.99, 17.01],
    rforest_china_base, rforest_china_ft, lstm_china_base, lstm_china_ft
]

usa_metrics = [
    [2655.09, 3378.09, 13.15], [3200.04, 3200.04, 17.13], [3200.04, 3594.01, 17.13],
    [3386.28, 3852.05, 18.42], [3201.13, 3754.82, 17.05], [3289.87, 3823.54, 18.25],
    rforest_usa_base, rforest_usa_ft, lstm_usa_base, lstm_usa_ft
]

ue_metrics = [
    [1850.40, 2349.37, 11.36], [1655.75, 1655.75, 10.51], [1676.57, 1959.45, 10.47],
    [1582.40, 1854.48, 9.81], [1797.66, 2076.38, 11.35], [2028.48, 2355.94, 13.46],
    rforest_ue_base, rforest_ue_ft, lstm_ue_base, lstm_ue_ft
]

# Crear DataFrame
comparison_df = pd.DataFrame({
    "Modelo": model_names,
    "China_MAE": [x[0] for x in china_metrics],
    "China_RMSE": [x[1] for x in china_metrics],
    "China_MAPE": [x[2] for x in china_metrics],
    "USA_MAE": [x[0] for x in usa_metrics],
    "USA_RMSE": [x[1] for x in usa_metrics],
    "USA_MAPE": [x[2] for x in usa_metrics],
    "UE_MAE": [x[0] for x in ue_metrics],
    "UE_RMSE": [x[1] for x in ue_metrics],
    "UE_MAPE": [x[2] for x in ue_metrics]
})

# Ordenar columnas si lo deseas
comparison_df = comparison_df[[
    "Modelo",
    "China_MAE", "China_RMSE", "China_MAPE",
    "USA_MAE", "USA_RMSE", "USA_MAPE",
    "UE_MAE", "UE_RMSE", "UE_MAPE"
]]

print("=== COMPARACIÓN DE MODELOS ===")
print(comparison_df.to_string(index=False))

###############################################################################
# 3. GRÁFICOS DE BARRAS PARA COMPARAR MÉTRICAS
###############################################################################

# --- A) Comparar MAPE de todos los modelos en cada país ---
fig, ax = plt.subplots(1, 3, figsize=(18, 6), sharey=True)

ax[0].bar(model_names, comparison_df["China_MAPE"], color='skyblue')
ax[0].set_title('MAPE - China')
ax[0].set_xticklabels(model_names, rotation=45, ha='right')
ax[0].set_ylabel('MAPE (%)')

ax[1].bar(model_names, comparison_df["USA_MAPE"], color='orange')
ax[1].set_title('MAPE - USA')
ax[1].set_xticklabels(model_names, rotation=45, ha='right')

ax[2].bar(model_names, comparison_df["UE_MAPE"], color='green')
ax[2].set_title('MAPE - UE')
ax[2].set_xticklabels(model_names, rotation=45, ha='right')

plt.tight_layout()
plt.show()
# Out:
# === COMPARACIÓN DE MODELOS ===
#              Modelo  China_MAE  China_RMSE  China_MAPE  USA_MAE  USA_RMSE  USA_MAPE  UE_MAE  UE_RMSE  UE_MAPE
#         SARIMA Base    6380.30     7763.23       12.38  2655.09   3378.09     13.15 1850.40  2349.37    11.36
#           SARIMA CV    7545.44     7545.44       14.22  3200.04   3200.04     17.13 1655.75  1655.75    10.51
# SARIMA CV Mes a Mes    7292.14     8301.72       13.85  3200.04   3594.01     17.13 1676.57  1959.45    10.47
#          SARIMA Log    8181.65     9858.39       15.74  3386.28   3852.05     18.42 1582.40  1854.48     9.81
#      SARIMA Box-Cox    7903.00     9053.29       14.94  3201.13   3754.82     17.05 1797.66  2076.38    11.35
#        SARIMA 2020+    8838.79    10451.99       17.01  3289.87   3823.54     18.25 2028.48  2355.94    13.46
#             RF Base   14354.22    15905.14       24.31  4207.72   6427.25     19.77 3171.52  4732.29    18.24
#       RF Fine-Tuned   14565.94    16003.35       24.70  3958.90   6295.97     18.23 2979.67  4630.26    17.42
#           LSTM Base   12000.00    14000.00       20.00  3500.00   5000.00     18.00 2800.00  4200.00    16.50
#     LSTM Fine-Tuned   11500.00    13500.00       19.50  3300.00   4800.00     17.50 2600.00  4000.00    15.80
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6284\901290351.py:89: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[0].set_xticklabels(model_names, rotation=45, ha='right')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6284\901290351.py:94: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(model_names, rotation=45, ha='right')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6284\901290351.py:98: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[2].set_xticklabels(model_names, rotation=45, ha='right')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import streamlit as st

###############################################################################
# 1. MÉTRICAS OBTENIDAS DE LOS MODELOS
###############################################################################

# Resultados SARIMA (ya proporcionados en tu código original)
# Resultados Random Forest (de la imagen)
rforest_china_base = [14354.22, 15905.14, 24.31]
rforest_china_ft = [14565.94, 16003.35, 24.70]
rforest_usa_base = [4207.72, 6427.25, 19.77]
rforest_usa_ft = [3958.90, 6295.97, 18.23]
rforest_ue_base = [3171.52, 4732.29, 18.24]
rforest_ue_ft = [2979.67, 4630.26, 17.42]

# Valores ficticios para LSTM (modelo base y fine-tuned)
lstm_china_base = [12000.00, 14000.00, 20.00]
lstm_china_ft = [11500.00, 13500.00, 19.50]
lstm_usa_base = [3500.00, 5000.00, 18.00]
lstm_usa_ft = [3300.00, 4800.00, 17.50]
lstm_ue_base = [2800.00, 4200.00, 16.50]
lstm_ue_ft = [2600.00, 4000.00, 15.80]

###############################################################################
# 2. CREAR TABLA COMPARATIVA EN PANDAS
###############################################################################

model_names = [
    "SARIMA Base", "SARIMA CV", "SARIMA CV Mes a Mes", "SARIMA Log",
    "SARIMA Box-Cox", "SARIMA 2020+",
    "RF Base", "RF Fine-Tuned",
    "LSTM Base", "LSTM Fine-Tuned"
]

# Consolidar los resultados para cada país
china_metrics = [
    [6380.30, 7763.23, 12.38], [7545.44, 7545.44, 14.22], [7292.14, 8301.72, 13.85],
    [8181.65, 9858.39, 15.74], [7903.00, 9053.29, 14.94], [8838.79, 10451.99, 17.01],
    rforest_china_base, rforest_china_ft, lstm_china_base, lstm_china_ft
]

usa_metrics = [
    [2655.09, 3378.09, 13.15], [3200.04, 3200.04, 17.13], [3200.04, 3594.01, 17.13],
    [3386.28, 3852.05, 18.42], [3201.13, 3754.82, 17.05], [3289.87, 3823.54, 18.25],
    rforest_usa_base, rforest_usa_ft, lstm_usa_base, lstm_usa_ft
]

ue_metrics = [
    [1850.40, 2349.37, 11.36], [1655.75, 1655.75, 10.51], [1676.57, 1959.45, 10.47],
    [1582.40, 1854.48, 9.81], [1797.66, 2076.38, 11.35], [2028.48, 2355.94, 13.46],
    rforest_ue_base, rforest_ue_ft, lstm_ue_base, lstm_ue_ft
]

# Crear DataFrame
comparison_df = pd.DataFrame({
    "Modelo": model_names,
    "China_MAE": [x[0] for x in china_metrics],
    "China_RMSE": [x[1] for x in china_metrics],
    "China_MAPE": [x[2] for x in china_metrics],
    "USA_MAE": [x[0] for x in usa_metrics],
    "USA_RMSE": [x[1] for x in usa_metrics],
    "USA_MAPE": [x[2] for x in usa_metrics],
    "UE_MAE": [x[0] for x in ue_metrics],
    "UE_RMSE": [x[1] for x in ue_metrics],
    "UE_MAPE": [x[2] for x in ue_metrics]
})

# Ordenar columnas si lo deseas
comparison_df = comparison_df[[
    "Modelo",
    "China_MAE", "China_RMSE", "China_MAPE",
    "USA_MAE", "USA_RMSE", "USA_MAPE",
    "UE_MAE", "UE_RMSE", "UE_MAPE"
]]

###############################################################################
# 3. PUBLICAR GRÁFICOS EN STREAMLIT
###############################################################################

st.title("Comparación de Modelos")

st.write("### Tabla Comparativa de Métricas")
st.dataframe(comparison_df)

st.write("### Gráficos de MAPE")
fig, ax = plt.subplots(1, 3, figsize=(18, 6), sharey=True)

ax[0].bar(model_names, comparison_df["China_MAPE"], color='skyblue')
ax[0].set_title('MAPE - China')
ax[0].set_xticklabels(model_names, rotation=45, ha='right')
ax[0].set_ylabel('MAPE (%)')

ax[1].bar(model_names, comparison_df["USA_MAPE"], color='orange')
ax[1].set_title('MAPE - USA')
ax[1].set_xticklabels(model_names, rotation=45, ha='right')

ax[2].bar(model_names, comparison_df["UE_MAPE"], color='green')
ax[2].set_title('MAPE - UE')
ax[2].set_xticklabels(model_names, rotation=45, ha='right')

st.pyplot(fig)

st.write("### Gráficos de MAE")
fig, ax = plt.subplots(1, 3, figsize=(18, 6), sharey=True)

ax[0].bar(model_names, comparison_df["China_MAE"], color='skyblue')
ax[0].set_title('MAE - China')
ax[0].set_xticklabels(model_names, rotation=45, ha='right')
ax[0].set_ylabel('MAE')

ax[1].bar(model_names, comparison_df["USA_MAE"], color='orange')
ax[1].set_title('MAE - USA')
ax[1].set_xticklabels(model_names, rotation=45, ha='right')

ax[2].bar(model_names, comparison_df["UE_MAE"], color='green')
ax[2].set_title('MAE - UE')
ax[2].set_xticklabels(model_names, rotation=45, ha='right')

st.pyplot(fig)

st.write("### Gráficos de RMSE")
fig, ax = plt.subplots(1, 3, figsize=(18, 6), sharey=True)

ax[0].bar(model_names, comparison_df["China_RMSE"], color='skyblue')
ax[0].set_title('RMSE - China')
ax[0].set_xticklabels(model_names, rotation=45, ha='right')
ax[0].set_ylabel('RMSE')

ax[1].bar(model_names, comparison_df["USA_RMSE"], color='orange')
ax[1].set_title('RMSE - USA')
ax[1].set_xticklabels(model_names, rotation=45, ha='right')

ax[2].bar(model_names, comparison_df["UE_RMSE"], color='green')
ax[2].set_title('RMSE - UE')
ax[2].set_xticklabels(model_names, rotation=45, ha='right')

st.pyplot(fig)
# Out:
# 2025-01-12 21:14:43.657 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-12 21:14:44.241
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\Users\ASUS\anaconda3\envs\timeseries_env\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-01-12 21:14:44.242 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-12 21:14:44.244 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-12 21:14:44.246 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-12 21:14:44.247 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-12 21:14:44.248 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-12 21:14:44.277 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-12 21:14:44.278 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-12 21:14:44.281 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-12 21:14:44.282 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-12 21:14:44.284 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-12 21:14:44.285 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6284\3981714679.py:92: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[0].set_xticklabels(model_names, rotation=45, ha='right')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6284\3981714679.py:97: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(model_names, rotation=45, ha='right')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6284\3981714679.py:101: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[2].set_xticklabels(model_names, rotation=45, ha='right')
# 2025-01-12 21:14:44.392 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-12 21:14:45.201 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-12 21:14:45.202 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-12 21:14:45.203 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-12 21:14:45.204 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-12 21:14:45.205 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-12 21:14:45.205 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6284\3981714679.py:110: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[0].set_xticklabels(model_names, rotation=45, ha='right')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6284\3981714679.py:115: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(model_names, rotation=45, ha='right')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6284\3981714679.py:119: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[2].set_xticklabels(model_names, rotation=45, ha='right')
# 2025-01-12 21:14:45.322 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-12 21:14:46.046 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-12 21:14:46.048 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-12 21:14:46.048 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-12 21:14:46.049 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-12 21:14:46.049 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-12 21:14:46.051 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6284\3981714679.py:128: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[0].set_xticklabels(model_names, rotation=45, ha='right')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6284\3981714679.py:133: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[1].set_xticklabels(model_names, rotation=45, ha='right')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6284\3981714679.py:137: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[2].set_xticklabels(model_names, rotation=45, ha='right')
# 2025-01-12 21:14:46.153 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-12 21:14:46.906 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-12 21:14:46.908 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
